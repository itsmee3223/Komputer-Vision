# %%
import numpy as np
import cv2 as cv

img = cv.imread("./images/color_ball.jpg")
cv.imshow("gambar", img)
# baca basic informasi
print(type(img)) #type dari img yang sudah diread
print(img.shape)
img = cv.cvtColor(img, cv.COLOR_BGR2HSV)
#get pixel in BGR format
print(img[133,237,:])
print(img[188,466,:])
print(img[343,160,:])

while(True):
    if cv.waitKey(1) & 0xFF == ord('q'):
        break
# Out:
# <class 'numpy.ndarray'>
# (670, 719, 3)
# [133 162 170]
# [179 243 230]
# [ 62 190 180]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# f:\computer vision\latihan_3.ipynb Cell 1 in <cell line: 15>()
#      <a href='vscode-notebook-cell:/f%3A/computer%20vision/latihan_3.ipynb#W0sZmlsZQ%3D%3D?line=12'>13</a> print(img[343,160,:])
#      <a href='vscode-notebook-cell:/f%3A/computer%20vision/latihan_3.ipynb#W0sZmlsZQ%3D%3D?line=14'>15</a> while(True):
# ---> <a href='vscode-notebook-cell:/f%3A/computer%20vision/latihan_3.ipynb#W0sZmlsZQ%3D%3D?line=15'>16</a>     if cv.waitKey(1) & 0xFF == ord('q'):
#      <a href='vscode-notebook-cell:/f%3A/computer%20vision/latihan_3.ipynb#W0sZmlsZQ%3D%3D?line=16'>17</a>         break
#
# KeyboardInterrupt:
