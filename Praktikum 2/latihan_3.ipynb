# %%
import numpy as np
import cv2
from google.colab.patches import cv2_imshow

img = cv2.imread("/content/drive/MyDrive/Colab Notebooks/Komputer Vision/images/color_ball.jpg")
cv2_imshow(img)
# baca basic informasi
print(type(img)) #type dari img yang sudah diread
print(img.shape)
img = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
#get pixel in BGR format
print(img[133,237,:])
print(img[188,466,:])
print(img[343,160,:])
# Out:
# <PIL.Image.Image image mode=RGB size=719x670 at 0x7FD90619BAD0>
# <class 'numpy.ndarray'>
# (670, 719, 3)
# [133 162 170]
# [179 243 230]
# [ 62 190 180]
