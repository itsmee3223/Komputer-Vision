# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
from PIL import Image, ImageFilter
import cv2
from google.colab.patches import cv2_imshow

image = Image.open(r"/content/drive/MyDrive/Colab Notebooks/Komputer Vision/gambar_uts/soal2/cball.jpg")
image = image.convert("L")
 
image = image.filter(ImageFilter.FIND_EDGES)

image.save(r"/content/drive/MyDrive/Colab Notebooks/Komputer Vision/gambar_uts/soal2/cball_out.jpg")

# %%
image_input = cv2.imread("/content/drive/MyDrive/Colab Notebooks/Komputer Vision/gambar_uts/soal2/cball.jpg")
image_output = cv2.imread("/content/drive/MyDrive/Colab Notebooks/Komputer Vision/gambar_uts/soal2/cball_out.jpg")


cv2_imshow(image_input)
cv2_imshow(image_output)
# Out:
# <PIL.Image.Image image mode=RGB size=670x719 at 0x7F78B47267F0>
# <PIL.Image.Image image mode=RGB size=670x719 at 0x7F78B0E51E50>
